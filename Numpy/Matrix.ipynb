# %%
import numpy as np

# %%
x=np.array([[1,2,3],[4,5,6],[3,6,7]])
y=np.array([[3,4,5],[9,5,7]])
dot=np.dot(y,x)
print(y@x)

values, vectors = np.linalg.eig(x)
print(values)
# print(vectors)
# Out:
# [[ 34  56  68]
#  [ 50  85 106]]
# [13.478192+0.j         -0.239096+0.62289379j -0.239096-0.62289379j]
