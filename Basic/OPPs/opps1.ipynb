# %%
class Persion:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        
    def greet(self):
        print("Name:",self.name)
        print("Age:",self.age)
        
p=Persion("Uthoaingyo",21)       
p.greet()
# Out:
# Name: Uthoaingyo
# Age: 21

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("Emil", 36)

print(p1)
