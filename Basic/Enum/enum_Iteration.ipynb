# %%
from enum import Enum

class Color(Enum):
 red = 1
 green = 2
 blue = 3
[c for c in Color]

print(Color(2))
print(Color['red'])
# Out:
# Color.green
# Color.red

# %%
from enum import Enum
class Color(Enum):
 red = 1
 green = 2
 blue = 3
print(Color.red) # Color.red
print(Color(1)) # Color.red
print(Color['red']) # Color.red
# Out:
# Color.red
# Color.red
# Color.red
